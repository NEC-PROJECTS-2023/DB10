# %%
import pandas as pd
import numpy as nm
import matplotlib.pyplot as plt
import seaborn as sns

# %%
admission=pd.read_csv( r"C:\Users\Koti Jammula\Downloads\Project\a.csv")
admission
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# 0           1              0.92
# 1           1              0.76
# 2           1              0.72
# 3           1              0.80
# 4           0              0.65
# ..        ...               ...
# 395         1              0.82
# 396         1              0.84
# 397         1              0.91
# 398         0              0.67
# 399         1              0.95
#
# [400 rows x 9 columns]

# %%
admission.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
admission.drop('Serial No.',axis=1,inplace=True)

# %%
admission.head(4)
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0        337          118                  4  4.5   4.5  9.65         1
# 1        324          107                  4  4.0   4.5  8.87         1
# 2        316          104                  3  3.0   3.5  8.00         1
# 3        322          110                  3  3.5   2.5  8.67         1
#
#    Chance of Admit
# 0              0.92
# 1              0.76
# 2              0.72
# 3              0.80

# %%
admission.isnull().sum()
# Out:
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
admission.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   GRE Score          400 non-null    int64
#  1   TOEFL Score        400 non-null    int64
#  2   University Rating  400 non-null    int64
#  3   SOP                400 non-null    float64
#  4   LOR                400 non-null    float64
#  5   CGPA               400 non-null    float64
#  6   Research           400 non-null    int64
#  7   Chance of Admit    400 non-null    float64
# dtypes: float64(4), int64(4)
# memory usage: 25.1 KB

# %%
admission.describe()
# Out:
#         GRE Score  TOEFL Score  University Rating         SOP        LOR   \
# count  400.000000   400.000000         400.000000  400.000000  400.000000
# mean   316.807500   107.410000           3.087500    3.400000    3.452500
# std     11.473646     6.069514           1.143728    1.006869    0.898478
# min    290.000000    92.000000           1.000000    1.000000    1.000000
# 25%    308.000000   103.000000           2.000000    2.500000    3.000000
# 50%    317.000000   107.000000           3.000000    3.500000    3.500000
# 75%    325.000000   112.000000           4.000000    4.000000    4.000000
# max    340.000000   120.000000           5.000000    5.000000    5.000000
#
#              CGPA    Research  Chance of Admit
# count  400.000000  400.000000        400.000000
# mean     8.598925    0.547500          0.724350
# std      0.596317    0.498362          0.142609
# min      6.800000    0.000000          0.340000
# 25%      8.170000    0.000000          0.640000
# 50%      8.610000    1.000000          0.730000
# 75%      9.062500    1.000000          0.830000
# max      9.920000    1.000000          0.970000

# %%
admission.corr()
# Out:
#                    GRE Score  TOEFL Score  University Rating       SOP  \
# GRE Score           1.000000     0.835977           0.668976  0.612831
# TOEFL Score         0.835977     1.000000           0.695590  0.657981
# University Rating   0.668976     0.695590           1.000000  0.734523
# SOP                 0.612831     0.657981           0.734523  1.000000
# LOR                 0.557555     0.567721           0.660123  0.729593
# CGPA                0.833060     0.828417           0.746479  0.718144
# Research            0.580391     0.489858           0.447783  0.444029
# Chance of Admit     0.802610     0.791594           0.711250  0.675732
#
#                        LOR       CGPA  Research  Chance of Admit
# GRE Score          0.557555  0.833060  0.580391          0.802610
# TOEFL Score        0.567721  0.828417  0.489858          0.791594
# University Rating  0.660123  0.746479  0.447783          0.711250
# SOP                0.729593  0.718144  0.444029          0.675732
# LOR                1.000000  0.670211  0.396859          0.669889
# CGPA               0.670211  1.000000  0.521654          0.873289
# Research           0.396859  0.521654  1.000000          0.553202
# Chance of Admit    0.669889  0.873289  0.553202          1.000000

# %%
# Heatmap for correlation matrix
corr_matrix = admission.corr()
plt.figure(figsize=(9,9,))
sns.heatmap(corr_matrix, annot=True)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#plot diagram for admission data
sns.pairplot(admission)

# %%
# heatmp for heads of admission
plt.figure(figsize=(10,6,))
sns.heatmap(admission.head(),annot=True,linewidths=0)
plt.show()

# %%
admission['GRE Score'].plot(figsize=(11,8))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Splitting Input and output data

# %%
x = admission.iloc[:,[0,1,2,3,4,5,6]]
x
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 395        324          110                  3  3.5   3.5  9.04         1
# 396        325          107                  3  3.0   3.5  9.11         1
# 397        330          116                  4  5.0   4.5  9.45         1
# 398        312          103                  3  3.5   4.0  8.78         0
# 399        333          117                  4  5.0   4.0  9.66         1
#
# [400 rows x 7 columns]

# %%
x.head(3)
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research
# 0        337          118                  4  4.5   4.5  9.65         1
# 1        324          107                  4  4.0   4.5  8.87         1
# 2        316          104                  3  3.0   3.5  8.00         1

# %%
import pandas as pd

# %% [markdown]
# #admission.rename(columns = {'Chance of Admit':'AdmitChance'}, inplace = True)
# #admission.columns

# %%
y=admission.iloc[:,[7]]
y
# Out:
#      Chance of Admit
# 0                0.92
# 1                0.76
# 2                0.72
# 3                0.80
# 4                0.65
# ..                ...
# 395              0.82
# 396              0.84
# 397              0.91
# 398              0.67
# 399              0.95
#
# [400 rows x 1 columns]

# %% [markdown]
# # Applying Model

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rnd_reg = RandomForestRegressor(n_estimators=20)       
rnd_reg
# Out:
# RandomForestRegressor(n_estimators=20)

# %%
rnd_reg.fit(x,y)
# Out:
# C:\Users\Koti Jammula\AppData\Local\Temp\ipykernel_6124\1836664633.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rnd_reg.fit(x,y)
# RandomForestRegressor(n_estimators=20)

# %%
admission.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   GRE Score          400 non-null    int64
#  1   TOEFL Score        400 non-null    int64
#  2   University Rating  400 non-null    int64
#  3   SOP                400 non-null    float64
#  4   LOR                400 non-null    float64
#  5   CGPA               400 non-null    float64
#  6   Research           400 non-null    int64
#  7   Chance of Admit    400 non-null    float64
# dtypes: float64(4), int64(4)
# memory usage: 25.1 KB

# %%
admission.corr()
# Out:
#                    GRE Score  TOEFL Score  University Rating       SOP  \
# GRE Score           1.000000     0.835977           0.668976  0.612831
# TOEFL Score         0.835977     1.000000           0.695590  0.657981
# University Rating   0.668976     0.695590           1.000000  0.734523
# SOP                 0.612831     0.657981           0.734523  1.000000
# LOR                 0.557555     0.567721           0.660123  0.729593
# CGPA                0.833060     0.828417           0.746479  0.718144
# Research            0.580391     0.489858           0.447783  0.444029
# Chance of Admit     0.802610     0.791594           0.711250  0.675732
#
#                        LOR       CGPA  Research  Chance of Admit
# GRE Score          0.557555  0.833060  0.580391          0.802610
# TOEFL Score        0.567721  0.828417  0.489858          0.791594
# University Rating  0.660123  0.746479  0.447783          0.711250
# SOP                0.729593  0.718144  0.444029          0.675732
# LOR                1.000000  0.670211  0.396859          0.669889
# CGPA               0.670211  1.000000  0.521654          0.873289
# Research           0.396859  0.521654  1.000000          0.553202
# Chance of Admit    0.669889  0.873289  0.553202          1.000000

# %%
admission.shape
# Out:
# (400, 8)

# %%
rnd_reg.fit(x,y)
# Out:
# C:\Users\Koti Jammula\AppData\Local\Temp\ipykernel_6124\1836664633.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rnd_reg.fit(x,y)
# RandomForestRegressor(n_estimators=20)

# %%
### Bulk data prediction
y_pred1 = rnd_reg.predict(x)
print('admitting chance:', y_pred1)
# Out:
# admitting chance: [0.925  0.767  0.676  0.7855 0.6555 0.8985 0.726  0.6295 0.5225 0.548
#  0.595  0.8305 0.8045 0.583  0.6185 0.5685 0.7015 0.6725 0.6615 0.6115
#  0.6295 0.6885 0.937  0.9335 0.9685 0.945  0.766  0.4435 0.468  0.534
#  0.638  0.696  0.9125 0.911  0.948  0.8835 0.643  0.5615 0.517  0.522
#  0.513  0.574  0.5675 0.855  0.906  0.871  0.8675 0.901  0.804  0.7515
#  0.747  0.558  0.731  0.702  0.68   0.6415 0.5985 0.4695 0.401  0.52
#  0.553  0.545  0.571  0.6055 0.62   0.64   0.6345 0.635  0.764  0.807
#  0.941  0.9545 0.9215 0.823  0.7475 0.735  0.75   0.6395 0.433  0.4645
#  0.55   0.952  0.9045 0.9145 0.9275 0.7325 0.7065 0.6575 0.6565 0.7595
#  0.6565 0.3995 0.479  0.4805 0.378  0.438  0.514  0.849  0.904  0.7945
#  0.713  0.65   0.6085 0.617  0.756  0.737  0.8695 0.913  0.9285 0.6745
#  0.63   0.715  0.6385 0.708  0.6285 0.6875 0.59   0.467  0.4595 0.7495
#  0.9405 0.941  0.6035 0.648  0.611  0.674  0.8685 0.757  0.817  0.9225
#  0.9605 0.733  0.6845 0.7835 0.892  0.793  0.7375 0.6695 0.804  0.7655
#  0.8335 0.9115 0.924  0.966  0.794  0.751  0.7325 0.827  0.959  0.7265
#  0.9175 0.92   0.862  0.7675 0.7625 0.7565 0.7115 0.6625 0.6145 0.559
#  0.5545 0.498  0.692  0.687  0.8175 0.794  0.647  0.659  0.625  0.5845
#  0.6645 0.888  0.848  0.886  0.852  0.8115 0.892  0.784  0.6665 0.694
#  0.687  0.668  0.6315 0.7385 0.7095 0.8665 0.788  0.924  0.9255 0.8785
#  0.8875 0.855  0.8045 0.94   0.7665 0.7225 0.7135 0.7135 0.7065 0.7255
#  0.7295 0.6965 0.968  0.9665 0.6695 0.512  0.605  0.62   0.6265 0.675
#  0.7995 0.8255 0.951  0.9625 0.93   0.9255 0.895  0.839  0.8225 0.719
#  0.7505 0.734  0.7645 0.697  0.649  0.603  0.639  0.651  0.698  0.8035
#  0.733  0.7275 0.698  0.6375 0.8985 0.8865 0.853  0.867  0.688  0.581
#  0.5765 0.645  0.732  0.763  0.6605 0.8095 0.72   0.6855 0.799  0.776
#  0.7335 0.71   0.7145 0.9265 0.845  0.7635 0.7245 0.749  0.7785 0.911
#  0.8655 0.7085 0.688  0.7235 0.748  0.7255 0.7065 0.7175 0.847  0.7615
#  0.6535 0.5275 0.4885 0.522  0.5605 0.7865 0.8985 0.704  0.6675 0.678
#  0.6965 0.7965 0.7905 0.786  0.941  0.9135 0.9    0.8865 0.787  0.7745
#  0.5515 0.5585 0.561  0.632  0.6275 0.694  0.7405 0.843  0.898  0.7015
#  0.6095 0.691  0.688  0.7215 0.6245 0.751  0.808  0.804  0.688  0.6545
#  0.7755 0.8385 0.7635 0.656  0.646  0.6455 0.5615 0.579  0.764  0.79
#  0.714  0.7245 0.7045 0.616  0.6835 0.813  0.595  0.6465 0.786  0.4755
#  0.794  0.701  0.6985 0.7325 0.733  0.827  0.7005 0.936  0.8025 0.786
#  0.737  0.775  0.606  0.614  0.4555 0.5235 0.4705 0.4475 0.52   0.6265
#  0.731  0.751  0.6305 0.637  0.5705 0.699  0.767  0.6465 0.6075 0.709
#  0.7935 0.9275 0.903  0.678  0.769  0.8545 0.741  0.534  0.524  0.603
#  0.6875 0.853  0.947  0.7715 0.475  0.428  0.377  0.485  0.4995 0.6925
#  0.78   0.7295 0.825  0.63   0.9545 0.9595 0.48   0.6085 0.5425 0.748
#  0.644  0.704  0.838  0.7545 0.8765 0.8075 0.8255 0.9125 0.696  0.9475]

# %%
admission.head(2)
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0        337          118                  4  4.5   4.5  9.65         1
# 1        324          107                  4  4.0   4.5  8.87         1
#
#    Chance of Admit
# 0              0.92
# 1              0.76

# %%
rnd_reg.predict([[330,100,1,6.0,7.5,9.4,0]])
# Out:
# C:\Users\Koti Jammula\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([0.908])

# %% [markdown]
# # pickle

# %%
import pickle
import numpy as np

# %%
pickle.dump(rnd_reg, open('rnd_reg.pkl','wb'))

# %%
rnd_model=pickle.load(open('rnd_reg.pkl','rb'))
rnd_model.predict([[320, 110, 1, 5, 5, 9, 1]])
# Out:
# C:\Users\Koti Jammula\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([0.8235])

# %% [markdown]
# # Accuracy score

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy2=rnd_reg.score(x,y)
accuracy2
# Out:
# 0.9608540117227758

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
scaler_x = StandardScaler()
x = scaler_x.fit_transform(x)

# %%
scaler_y = StandardScaler()
y = scaler_y.fit_transform(y)

# %%
y_predict_orig = scaler_y.inverse_transform(y)
y_test_orig = scaler_y.inverse_transform(x)

# %%
plt.plot(y_test_orig, y_predict_orig, '^', color='r')
# Out:
# [<matplotlib.lines.Line2D at 0x24101ad4d60>,
#  <matplotlib.lines.Line2D at 0x24101ad4e20>,
#  <matplotlib.lines.Line2D at 0x24101ad4f40>,
#  <matplotlib.lines.Line2D at 0x24101ae00a0>,
#  <matplotlib.lines.Line2D at 0x24101ae01c0>,
#  <matplotlib.lines.Line2D at 0x24101ae02e0>,
#  <matplotlib.lines.Line2D at 0x24101ae0400>]
